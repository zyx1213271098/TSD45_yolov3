# %%
import numpy as np
import matplotlib.pyplot as plt
import pylab as pl
import os
import sys
import time
import anno_func, json
import random
import copy
from collections import Counter
from math import fabs
from PIL import Image
import pandas as pd
from IPython.display import display

# %matplotlib inline

# %%
datadir = "../tsd-data"

filedir = os.path.join(datadir,"valid_target.json")
TT100K_dir=os.path.join(datadir,"TT100K_target.json")
oannos=json.loads(open(TT100K_dir).read())
annos = json.loads(open(filedir).read())

results_annos0=json.loads(open(os.path.join(datadir, "TT100K_predict.json")).read())
result_anno_file =  os.path.join(datadir, "yolov3_predict.json")
results_annos1 = json.loads(open(result_anno_file).read())

# result_anno_file=os.path.join(datadir,"resnet101_predict.json")
# results_annos2=json.loads(open(result_anno_file).read())

# result_anno_file=os.path.join(datadir,"resnet152_predict.json")
# results_annos3=json.loads(open(result_anno_file).read())

# %%
print (len(results_annos1['imgs']))
sm = anno_func.eval_annos(annos, results_annos1, iou=0.5,types=anno_func.type42,minscore=50,check_type=False,minboxsize=96, maxboxsize=400)
print sm['report']
# Out:
# 7369
# iou:0.5, size:[(96,400), types:none, acc:0.924548352816, rec:0.790909090909, ac_c:870, ac_n:941, rc_c:870, rc_n:1100

# %%
# print (len(results_annos2['imgs']))
# sm = anno_func.eval_annos(annos, results_annos2, iou=0.5,types=anno_func.type42,minscore=50,check_type=True,minboxsize=96, maxboxsize=400)
# print sm['report']
# Out:
# 7369
# iou:0.5, size:[(96,400), types:[pl120,..total 42..], acc:0.904963041183, rec:0.779090909091, ac_c:857, ac_n:947, rc_c:857, rc_n:1100

# %%
# print (len(results_annos3['imgs']))
# sm = anno_func.eval_annos(annos, results_annos3, iou=0.5,types=anno_func.type42,minscore=50,check_type=True,minboxsize=0,maxboxsize=32)
# print sm['report']
# Out:
# 7369
# iou:0.5, size:[(0,32), types:[pl120,..total 42..], acc:0.868584180511, rec:0.865365612648, ac_c:7006, ac_n:8066, rc_c:7006, rc_n:8096

# %%
print (len(results_annos0['imgs']))
sm = anno_func.eval_annos(oannos, results_annos0, iou=0.5,types=anno_func.type42,minscore=50,check_type=True,minboxsize=96, maxboxsize=400)
print sm['report']
# Out:
# 3071
# iou:0.5, size:[(96,400), types:[pl120,..total 42..], acc:0.921568627451, rec:0.880403458213, ac_c:611, ac_n:663, rc_c:611, rc_n:694

# %%
sizes = [ anno_func.box_long_size(obj['bbox']) for k,img in annos['imgs'].items() for obj in img['objects']]
_ = pl.hist(sizes, bins=100)

# %%
reload(anno_func)
df=pd.DataFrame(index=['Precision','Recall'])
#test_annos = res_annos2
#minscore=0.5
test_annos = results_annos3
minscore=50

sm = anno_func.eval_annos(annos, test_annos, iou=0.5, check_type=True, types=anno_func.type42,
                         minboxsize=0,maxboxsize=400,minscore=minscore)
print sm['report']
sm = anno_func.eval_annos(annos, test_annos, iou=0.5, check_type=True, types=anno_func.type42,
                         minboxsize=0,maxboxsize=32,minscore=minscore)
print sm['report']
sm = anno_func.eval_annos(annos, test_annos, iou=0.5, check_type=True, types=anno_func.type42,
                         minboxsize=32,maxboxsize=96,minscore=minscore)
print sm['report']
sm = anno_func.eval_annos(annos, test_annos, iou=0.5, check_type=True, types=anno_func.type42,
                         minboxsize=96,maxboxsize=400,minscore=minscore)
print sm['report']

for tp in anno_func.type42:
    sm = anno_func.eval_annos(annos, test_annos, iou=0.5, check_type=True, types=[tp],minscore=minscore,minboxsize=32,maxboxsize=96)
    print(sm['report'])
# Out:
# iou:0.5, size:[(0,400), types:[pl120,..total 42..], acc:0.905436535361, rec:0.893193955232, ac_c:15722, ac_n:17364, rc_c:15722, rc_n:17602
# iou:0.5, size:[(0,32), types:[pl120,..total 42..], acc:0.868584180511, rec:0.865365612648, ac_c:7006, ac_n:8066, rc_c:7006, rc_n:8096
# iou:0.5, size:[(32,96), types:[pl120,..total 42..], acc:0.940979288878, rec:0.935046395432, ac_c:7860, ac_n:8353, rc_c:7860, rc_n:8406
# iou:0.5, size:[(96,400), types:[pl120,..total 42..], acc:0.90582010582, rec:0.778181818182, ac_c:856, ac_n:945, rc_c:856, rc_n:1100
# iou:0.5, size:[(32,96), types:i2, acc:0.943181818182, rec:0.864583333333, ac_c:166, ac_n:176, rc_c:166, rc_n:192
# iou:0.5, size:[(32,96), types:i4, acc:0.931558935361, rec:0.935114503817, ac_c:245, ac_n:263, rc_c:245, rc_n:262
# iou:0.5, size:[(32,96), types:i5, acc:0.966173361522, rec:0.93839835729, ac_c:457, ac_n:473, rc_c:457, rc_n:487
# iou:0.5, size:[(32,96), types:il100, acc:0.964601769912, rec:0.947826086957, ac_c:109, ac_n:113, rc_c:109, rc_n:115
# iou:0.5, size:[(32,96), types:il60, acc:0.964864864865, rec:0.932114882507, ac_c:357, ac_n:370, rc_c:357, rc_n:383
# iou:0.5, size:[(32,96), types:il80, acc:0.95, rec:0.988, ac_c:247, ac_n:260, rc_c:247, rc_n:250
# iou:0.5, size:[(32,96), types:ip, acc:1.0, rec:0.858823529412, ac_c:73, ac_n:73, rc_c:73, rc_n:85
# iou:0.5, size:[(32,96), types:p10, acc:0.818181818182, rec:0.913043478261, ac_c:63, ac_n:77, rc_c:63, rc_n:69
# iou:0.5, size:[(32,96), types:p11, acc:0.940217391304, rec:0.916961130742, ac_c:519, ac_n:552, rc_c:519, rc_n:566
# iou:0.5, size:[(32,96), types:p12, acc:0.818181818182, rec:0.891891891892, ac_c:99, ac_n:121, rc_c:99, rc_n:111
# iou:0.5, size:[(32,96), types:p19, acc:0.916666666667, rec:0.942857142857, ac_c:33, ac_n:36, rc_c:33, rc_n:35
# iou:0.5, size:[(32,96), types:p23, acc:0.9375, rec:0.89552238806, ac_c:60, ac_n:64, rc_c:60, rc_n:67
# iou:0.5, size:[(32,96), types:p26, acc:0.913888888889, rec:0.891598915989, ac_c:329, ac_n:360, rc_c:329, rc_n:369
# iou:0.5, size:[(32,96), types:p27, acc:0.876404494382, rec:0.829787234043, ac_c:78, ac_n:89, rc_c:78, rc_n:94
# iou:0.5, size:[(32,96), types:p3, acc:0.830985915493, rec:0.907692307692, ac_c:118, ac_n:142, rc_c:118, rc_n:130
# iou:0.5, size:[(32,96), types:p5, acc:0.989361702128, rec:0.96875, ac_c:93, ac_n:94, rc_c:93, rc_n:96
# iou:0.5, size:[(32,96), types:p6, acc:0.735849056604, rec:0.639344262295, ac_c:39, ac_n:53, rc_c:39, rc_n:61
# iou:0.5, size:[(32,96), types:pg, acc:0.923076923077, rec:0.972972972973, ac_c:36, ac_n:39, rc_c:36, rc_n:37
# iou:0.5, size:[(32,96), types:ph4, acc:0.769230769231, rec:0.882352941176, ac_c:30, ac_n:39, rc_c:30, rc_n:34
# iou:0.5, size:[(32,96), types:ph4.5, acc:0.878787878788, rec:0.878787878788, ac_c:58, ac_n:66, rc_c:58, rc_n:66
# iou:0.5, size:[(32,96), types:ph5, acc:0.686567164179, rec:0.901960784314, ac_c:46, ac_n:67, rc_c:46, rc_n:51
# iou:0.5, size:[(32,96), types:pl100, acc:0.974499089253, rec:0.978062157221, ac_c:535, ac_n:549, rc_c:535, rc_n:547
# iou:0.5, size:[(32,96), types:pl120, acc:0.957831325301, rec:0.987577639752, ac_c:159, ac_n:166, rc_c:159, rc_n:161
# iou:0.5, size:[(32,96), types:pl20, acc:0.972972972973, rec:0.857142857143, ac_c:36, ac_n:37, rc_c:36, rc_n:42
# iou:0.5, size:[(32,96), types:pl30, acc:0.944444444444, rec:0.939698492462, ac_c:187, ac_n:198, rc_c:187, rc_n:199
# iou:0.5, size:[(32,96), types:pl40, acc:0.973995271868, rec:0.951501154734, ac_c:412, ac_n:423, rc_c:412, rc_n:433
# iou:0.5, size:[(32,96), types:pl5, acc:0.930041152263, rec:0.896825396825, ac_c:226, ac_n:243, rc_c:226, rc_n:252
# iou:0.5, size:[(32,96), types:pl50, acc:0.954545454545, rec:0.935933147632, ac_c:336, ac_n:352, rc_c:336, rc_n:359
# iou:0.5, size:[(32,96), types:pl60, acc:0.949843260188, rec:0.952830188679, ac_c:303, ac_n:319, rc_c:303, rc_n:318
# iou:0.5, size:[(32,96), types:pl70, acc:0.97619047619, rec:0.964705882353, ac_c:82, ac_n:84, rc_c:82, rc_n:85
# iou:0.5, size:[(32,96), types:pl80, acc:0.981981981982, rec:0.926345609065, ac_c:327, ac_n:333, rc_c:327, rc_n:353
# iou:0.5, size:[(32,96), types:pm20, acc:0.886363636364, rec:0.975, ac_c:39, ac_n:44, rc_c:39, rc_n:40
# iou:0.5, size:[(32,96), types:pm30, acc:0.918918918919, rec:0.944444444444, ac_c:34, ac_n:37, rc_c:34, rc_n:36
# iou:0.5, size:[(32,96), types:pm55, acc:0.837209302326, rec:0.9, ac_c:36, ac_n:43, rc_c:36, rc_n:40
# iou:0.5, size:[(32,96), types:pn, acc:0.9638671875, rec:0.965753424658, ac_c:987, ac_n:1024, rc_c:987, rc_n:1022
# iou:0.5, size:[(32,96), types:pne, acc:0.955782312925, rec:0.950930626058, ac_c:562, ac_n:588, rc_c:562, rc_n:591
# iou:0.5, size:[(32,96), types:pr40, acc:0.946428571429, rec:0.963636363636, ac_c:53, ac_n:56, rc_c:53, rc_n:55
# iou:0.5, size:[(32,96), types:w13, acc:0.90625, rec:0.90625, ac_c:29, ac_n:32, rc_c:29, rc_n:32
# iou:0.5, size:[(32,96), types:w32, acc:1.0, rec:0.793103448276, ac_c:23, ac_n:23, rc_c:23, rc_n:29
# iou:0.5, size:[(32,96), types:w55, acc:0.758620689655, rec:0.942857142857, ac_c:66, ac_n:87, rc_c:66, rc_n:70
# iou:0.5, size:[(32,96), types:w57, acc:0.983870967742, rec:0.945736434109, ac_c:122, ac_n:124, rc_c:122, rc_n:129
# iou:0.5, size:[(32,96), types:w59, acc:0.879310344828, rec:0.962264150943, ac_c:51, ac_n:58, rc_c:51, rc_n:53

# %%
reload(anno_func)
def get_acc_res(results_annos, annos,**argv):
    scs = [ obj['score'] for k,img in results_annos['imgs'].items() for obj in img['objects']]
    scs = sorted(scs)
    #print(scs)
    accs = [0]
    recs = [1]
    for i, score in enumerate(np.linspace(0, scs[-1], 100)):
        sm = anno_func.eval_annos(annos, results_annos, iou=0.5, check_type=True, types=anno_func.type42, minscore=score, **argv)
        print "\r%s %s %s" % (i, score, sm['report']), 
        sys.stdout.flush()
        accs.append(sm['accuracy'])
        if len(accs)>=2 and accs[-1]<accs[-2]:
            accs[-1] = accs[-2]
        recs.append(sm['recall'])
    accs.append(1)
    recs.append(0)
    return accs, recs
sizes = [0,32,96,400]
ac_rc = []

for i in range(4):
    if i==3:
        l=sizes[0]
        r=sizes[-1]
    else:
        l=sizes[i]
        r=sizes[i+1]
    acc0, recs0=get_acc_res(results_annos0, oannos, minboxsize=l, maxboxsize=r)
    acc1, recs1 = get_acc_res(results_annos1, annos, minboxsize=l, maxboxsize=r)
    acc2, recs2 = get_acc_res(results_annos2, annos, minboxsize=l, maxboxsize=r)
    acc3, recs3=get_acc_res(results_annos3, annos, minboxsize=l, maxboxsize=r)
    ac_rc.append([acc0, recs0, acc1, recs1, acc2, recs2,acc3, recs3])
    
    pl.figure(figsize=(8,6))
    plt.plot(acc0, recs0, label='CVPR2016-TT100K')
    pl.plot(acc1, recs1, label='RetinaNet-50')
    pl.plot(acc2, recs2, label='RetinaNet-101')
    pl.plot(acc3, recs3, label='RetinaNet-152')
    pl.xlabel("accuracy")
    pl.ylabel("recall")
    pl.title("size: (%s,%s]"%(l,r))

    pl.legend(bbox_to_anchor=(0, 0), loc="lower left")
# Out:
# 99 99.9894738197 iou:0.5, size:[(0,400), types:[pl120,..total 42..], acc:1.0, rec:5.68117259402e-05, ac_c:1, ac_n:1, rc_c:1, rc_n:17602:4006, rc_n:17602602

# %%
def compute_AP(acc, res):
    AP=0
    for i in range(1,len(acc)):
        AP+=fabs(res[i]-res[i-1])*0.5*(acc[i-1]+acc[i])
    return AP

# %%
MAP0=compute_AP(acc0, recs0)
MAP1=compute_AP(acc1, recs1)
MAP2=compute_AP(acc2, recs2)
MAP3=compute_AP(acc3, recs3)
print('CVPR2016-TT100K','MAP: ',MAP0)
print('RetinaNet-50', 'MAP: ',MAP1)
print('RetinaNet-101', 'MAP: ',MAP2)
print('RetinaNet=152','MAP: ', MAP3)
# Out:
# ('CVPR2016-TT100K', 'MAP: ', 0.8979612288309989)
# ('RetinaNet-50', 'MAP: ', 0.7939715467764744)
# ('RetinaNet-101', 'MAP: ', 0.9202782889161175)
# ('RetinaNet=152', 'MAP: ', 0.9280140935583158)

# %%
# df=pd.wrint_excel('../data/AP.xlsx')
# display(df)
a = [ obj['score'] for k,img in results_annos0['imgs'].items() for obj in img['objects']]
a = sorted(a)
#print(a)
for i, score in enumerate(np.linspace(0, a[-1], 100)):
    print(i,score)
# Out:
# (0, 0.0)
# (1, 12.979797979797979)
# (2, 25.959595959595958)
# (3, 38.939393939393938)
# (4, 51.919191919191917)
# (5, 64.898989898989896)
# (6, 77.878787878787875)
# (7, 90.858585858585855)
# (8, 103.83838383838383)
# (9, 116.81818181818181)
# (10, 129.79797979797979)
# (11, 142.77777777777777)
# (12, 155.75757575757575)
# (13, 168.73737373737373)
# (14, 181.71717171717171)
# (15, 194.69696969696969)
# (16, 207.67676767676767)
# (17, 220.65656565656565)
# (18, 233.63636363636363)
# (19, 246.61616161616161)
# (20, 259.59595959595958)
# (21, 272.57575757575756)
# (22, 285.55555555555554)
# (23, 298.53535353535352)
# (24, 311.5151515151515)
# (25, 324.49494949494948)
# (26, 337.47474747474746)
# (27, 350.45454545454544)
# (28, 363.43434343434342)
# (29, 376.4141414141414)
# (30, 389.39393939393938)
# (31, 402.37373737373736)
# (32, 415.35353535353534)
# (33, 428.33333333333331)
# (34, 441.31313131313129)
# (35, 454.29292929292927)
# (36, 467.27272727272725)
# (37, 480.25252525252523)
# (38, 493.23232323232321)
# (39, 506.21212121212119)
# (40, 519.19191919191917)
# (41, 532.17171717171709)
# (42, 545.15151515151513)
# (43, 558.13131313131316)
# (44, 571.11111111111109)
# (45, 584.09090909090901)
# (46, 597.07070707070704)
# (47, 610.05050505050508)
# (48, 623.030303030303)
# (49, 636.01010101010093)
# (50, 648.98989898989896)
# (51, 661.969696969697)
# (52, 674.94949494949492)
# (53, 687.92929292929284)
# (54, 700.90909090909088)
# (55, 713.88888888888891)
# (56, 726.86868686868684)
# (57, 739.84848484848476)
# (58, 752.82828282828279)
# (59, 765.80808080808083)
# (60, 778.78787878787875)
# (61, 791.76767676767668)
# (62, 804.74747474747471)
# (63, 817.72727272727275)
# (64, 830.70707070707067)
# (65, 843.68686868686859)
# (66, 856.66666666666663)
# (67, 869.64646464646466)
# (68, 882.62626262626259)
# (69, 895.60606060606051)
# (70, 908.58585858585855)
# (71, 921.56565656565658)
# (72, 934.5454545454545)
# (73, 947.52525252525243)
# (74, 960.50505050505046)
# (75, 973.4848484848485)
# (76, 986.46464646464642)
# (77, 999.44444444444434)
# (78, 1012.4242424242424)
# (79, 1025.4040404040404)
# (80, 1038.3838383838383)
# (81, 1051.3636363636363)
# (82, 1064.3434343434342)
# (83, 1077.3232323232323)
# (84, 1090.3030303030303)
# (85, 1103.2828282828282)
# (86, 1116.2626262626263)
# (87, 1129.2424242424242)
# (88, 1142.2222222222222)
# (89, 1155.2020202020201)
# (90, 1168.181818181818)
# (91, 1181.1616161616162)
# (92, 1194.1414141414141)
# (93, 1207.121212121212)
# (94, 1220.1010101010102)
# (95, 1233.0808080808081)
# (96, 1246.060606060606)
# (97, 1259.0404040404039)
# (98, 1272.0202020202019)
# (99, 1285.0)

# %%
import cv2
import matplotlib.pyplot as plt
import numpy
# %matplotlib inline

img = cv2.imread('../samples/394_2_1.jpg')
hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
print(hsv.shape)
plt.figure()
plt.imshow(hsv[:,:,0],aspect='auto')
plt.figure()
plt.imshow(hsv[:,:,1],aspect='auto')
plt.figure()
plt.imshow(hsv[:,:,2],aspect='auto')

print(hsv[:,:,0],'\n')
print(numpy.max(hsv[:,:,0]))
print(hsv[:,:,1],'\n')
print(numpy.max(hsv[:,:,1]))
print(hsv[:,:,2],'\n')
print(numpy.max(hsv[:,:,2]))
# Out:
# (512, 512, 3)
# (array([[106, 106, 106, ..., 107, 107, 107],
#        [106, 106, 106, ..., 107, 107, 107],
#        [106, 106, 106, ..., 107, 107, 107],
#        ...,
#        [ 70,  70,  67, ..., 111, 111, 111],
#        [ 70,  70,  67, ..., 111, 111, 111],
#        [ 70,  70,  67, ..., 111, 111, 111]], dtype=uint8), '\n')
# 179
# (array([[25, 25, 25, ..., 40, 40, 40],
#        [25, 25, 25, ..., 40, 40, 40],
#        [25, 25, 25, ..., 40, 40, 40],
#        ...,
#        [56, 52, 49, ..., 22, 23, 24],
#        [58, 58, 57, ..., 22, 22, 23],
#        [55, 61, 64, ..., 22, 22, 22]], dtype=uint8), '\n')
# 255
# (array([[221, 221, 221, ..., 218, 218, 218],
#        [221, 221, 221, ..., 218, 218, 218],
#        [221, 221, 221, ..., 218, 218, 218],
#        ...,
#        [ 82,  89,  93, ..., 118, 113, 108],
#        [ 79,  79,  81, ..., 117, 114, 112],
#        [ 84,  75,  72, ..., 116, 115, 114]], dtype=uint8), '\n')
# 255
